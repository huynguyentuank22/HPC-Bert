# %%
import pandas as pd

# %%
df = pd.read_parquet("data/24_03.parquet")
df
# Out:
#                  jid       usr          jnam  cnumr  cnumat  cnumut  nnumr  \
# 0       jid_22765134  usr_1796  jnam_2238181  30720   30720   30720    640
# 1       jid_22765137  usr_3630  jnam_2261607    384     384     384      8
# 2       jid_22765138  usr_2111   jnam_215338     48      48      48      1
# 3       jid_22765139  usr_2111   jnam_215335     48      48      48      1
# 4       jid_22765141  usr_2111   jnam_215336     48      48      48      1
# ...              ...       ...           ...    ...     ...     ...    ...
# 508281  jid_23118247  usr_2900   jnam_101093     48      48      20      1
# 508282  jid_23118255  usr_2900   jnam_101093     48      48      20      1
# 508283  jid_23118498  usr_3623   jnam_179740     48      48      45      1
# 508284  jid_23118515  usr_3623   jnam_179740     48      48      48      1
# 508285  jid_23118526  usr_3623   jnam_179740     48      48      45      1
#
#                            adt                     qdt  \
# ...

# %%
df1 = pd.read_parquet("data/24_04.parquet")
df1
# Out:
#                  jid       usr          jnam  cnumr  cnumat  cnumut  nnumr  \
# 0       jid_23119017  usr_1795  jnam_2270304    768     768     768     16
# 1       jid_23119018  usr_1795  jnam_2270304    768     768     768     16
# 2       jid_23119020  usr_1795  jnam_2270304    768     768     768     16
# 3       jid_23119021  usr_1795  jnam_2270304    768     768     768     16
# 4       jid_23119022  usr_1795  jnam_2270304    768     768     768     16
# ...              ...       ...           ...    ...     ...     ...    ...
# 420445  jid_23452970  usr_3303  jnam_2226586   1536    1536    1289     32
# 420446  jid_23452971  usr_3303  jnam_2226586   1536    1536    1287     32
# 420447  jid_23452972  usr_3303  jnam_2226586   1536    1536    1285     32
# 420448  jid_23452973  usr_1795  jnam_2336046    768     768     768     16
# 420449  jid_23452974  usr_1795  jnam_2336046    768     768     768     16
#
#                            adt                     qdt  \
# ...

# %%
df2 = pd.read_parquet("data_embedding/24_04_embedding_only.parquet")
df2
# Out:
#                                            embedding_anon
# 0       [-0.16970095, -0.04135609, -0.025524642, -0.03...
# 1       [-0.16970095, -0.04135609, -0.025524642, -0.03...
# 2       [-0.16970095, -0.04135609, -0.025524642, -0.03...
# 3       [-0.16970095, -0.04135609, -0.025524642, -0.03...
# 4       [-0.16970095, -0.04135609, -0.025524642, -0.03...
# ...                                                   ...
# 420445  [-0.11453424, -0.053584035, -0.051872835, -0.0...
# 420446  [-0.11453424, -0.053584035, -0.051872835, -0.0...
# 420447  [-0.11453424, -0.053584035, -0.051872835, -0.0...
# 420448  [-0.1668178, -0.026931038, -0.020875571, -0.03...
# 420449  [-0.1668178, -0.026931038, -0.020875571, -0.03...
#
# [420450 rows x 1 columns]
