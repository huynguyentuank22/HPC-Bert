# %%
import pandas as pd

# %%
df = pd.read_parquet("data/21_03.parquet")
df
# Out:
#                jid      usr        jnam  cnumr  cnumat  cnumut  nnumr  \
# 0            jid_0    usr_0      jnam_0     48      48      48      1
# 1            jid_1    usr_0      jnam_0     48      48      48      1
# 2            jid_2    usr_0      jnam_0     48      48      48      1
# 3            jid_3    usr_0      jnam_0     48      48      48      1
# 4            jid_4    usr_0      jnam_0     48      48      48      1
# ...            ...      ...         ...    ...     ...     ...    ...
# 713612  jid_288349  usr_159    jnam_376    576     576     576     12
# 713613  jid_288349  usr_159    jnam_376    576     576     576     12
# 713614  jid_288349  usr_159    jnam_376    576     576     576     12
# 713615  jid_288349  usr_159    jnam_376    576     576     576     12
# 713616  jid_664001  usr_195  jnam_55921     48      48      48      1
#
#                            adt                     qdt  \
# 0       2021-03-04 03:51:06+09  2021-03-04 03:51:06+09
# ...

# %%
df1 = pd.read_parquet("data/21_04.parquet")
df1
# Out:
#                jid      usr        jnam  cnumr  cnumat  cnumut  nnumr  \
# 0       jid_664002  usr_286  jnam_14659    480     480       5     10
# 1       jid_664003  usr_222   jnam_1267     96      96      96      2
# 2       jid_664004  usr_310  jnam_55922     96      96      31      2
# 3       jid_664005  usr_285  jnam_14657  18432   18432     677    384
# 4       jid_664006  usr_285  jnam_14657  18432   18432     654    384
# ...            ...      ...         ...    ...     ...     ...    ...
# 116972  jid_767066   usr_13  jnam_40504    288     288     288      6
# 116973  jid_767066   usr_13  jnam_40504    288     288     288      6
# 116974  jid_767066   usr_13  jnam_40504    288     288     288      6
# 116975  jid_767066   usr_13  jnam_40504    288     288     288      6
# 116976  jid_767066   usr_13  jnam_40504    288     288     288      6
#
#                            adt                     qdt  \
# 0       2021-04-01 10:28:01+09  2021-04-01 10:28:01+09
# ...

# %%
df2 = pd.read_parquet("data_embedding/24_04_embedding_only.parquet")
df2
# Out:
#                                            embedding_anon
# 0       [-0.16970095, -0.04135609, -0.025524642, -0.03...
# 1       [-0.16970095, -0.04135609, -0.025524642, -0.03...
# 2       [-0.16970095, -0.04135609, -0.025524642, -0.03...
# 3       [-0.16970095, -0.04135609, -0.025524642, -0.03...
# 4       [-0.16970095, -0.04135609, -0.025524642, -0.03...
# ...                                                   ...
# 420445  [-0.11453424, -0.053584035, -0.051872835, -0.0...
# 420446  [-0.11453424, -0.053584035, -0.051872835, -0.0...
# 420447  [-0.11453424, -0.053584035, -0.051872835, -0.0...
# 420448  [-0.1668178, -0.026931038, -0.020875571, -0.03...
# 420449  [-0.1668178, -0.026931038, -0.020875571, -0.03...
#
# [420450 rows x 1 columns]
